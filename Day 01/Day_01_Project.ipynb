# %% [markdown]
# **Band Name Generator**

# %%
city_name = input("What's the name of the city you grew up in? ")
# Out:
# What's the name of the city you grew up in? Nashik

# %% [markdown]
# This asks the user for the name of the city they grew up in.

# %%
pet_name = input("what's your pet's name? ")
# Out:
# what's your pet's name? niggas

# %% [markdown]
# This asks the user for there pet's name.

# %%
print("Your band name could be " + city_name + " " + pet_name)
# Out:
# Your band name could be Nashik niggas

# %% [markdown]
# This line of code joints two variables (city_name & pet_name) then it prints the name of the band to the user
