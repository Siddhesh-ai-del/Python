# %% [markdown]
# 1. We use **print()** to display an text (string)
#
# 2. The "" are used to tell the computer, whatever is inside the "" is not code but it's a text

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# 1. **\n** Creates an new line !

# %%
print("Hello World\nHello Hell")
# Out:
# Hello World
# Hello Hell

# %% [markdown]
# 1. **String Concatenate:** We can joined two strings

# %%
print("Hello" + " You!")
# Out:
# Hello You

# %% [markdown]
# Solve The following bugs in the code
#
#
# ---
#
# 1. print(Notes from Day 1")
# 2. print("The print statement is used to output strings")
# 3. print("Strings are strings of characters"
# 4. priint("String Concatenation is done with the + sign")
# 5. print1(("New lines can be created with a \ and the letter n")

# %%
print("Notes from Day 1")
print("The print statement is used to output strings")
print("Strings are strings of characters")
print("String Concatenation is done with the + sign")
print("New lines can be created with the letter n")
# Out:
# Notes from Day 1
# The print statement is used to output strings
# Strings are strings of characters
# String Concatenation is done with the + sign
# New lines can be created with the letter n

# %% [markdown]
# 1. **input():** This function asks the user to input some data.
# 2. In order to save the data we will use **=** to assign the input value

# %%
name = input("What is your name? ")
print("Hello " + name)
# Out:
# What is your name? Siddhesh
# Hello Siddhesh

# %% [markdown]
# 1. **Variables:** These are used to store an value, which is assign by the user. in our case its **name**

# %%
name = input("What is your name? ")
# Out:
# What is your name? siddhesh

# %%
print(name)
# Out:
# siddhesh

# %% [markdown]
# 1. We will use **len()** to calculate how many characters are there in a string

# %%
len(name)
# Out:
# 8

# %% [markdown]
# **Solve**:
#
# glass1 contains milk and glass2 contains juice. Write 3 lines of code to switch the contents of the variables. You are not allowed to type the words "milk" or "juice". You are only allowed to use variables to solve this exercise.

# %%
glass1 = "milk"
glass2 = "juice"

temp = glass1
glass1 = glass2
print(glass1)
glass2 = temp
print(glass2)
# Out:
# juice
# milk

# %% [markdown]
# **Rules for variable naming:**
# 1. Make it readable (Should name sense)
# 2. Do not have space between words
# 3. Don't start with numbers
# 4. Don't use names of the functions!
